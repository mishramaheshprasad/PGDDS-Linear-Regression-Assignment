# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm 
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Reading and understanding the data

# %%
car_df = pd.read_csv("CarPrice_Assignment.csv")
car_df.head(20)
# Out:
#     car_ID  symboling                   CarName fueltype aspiration  \
# 0        1          3        alfa-romero giulia      gas        std
# 1        2          3       alfa-romero stelvio      gas        std
# 2        3          1  alfa-romero Quadrifoglio      gas        std
# 3        4          2               audi 100 ls      gas        std
# 4        5          2                audi 100ls      gas        std
# 5        6          2                  audi fox      gas        std
# 6        7          1                audi 100ls      gas        std
# 7        8          1                 audi 5000      gas        std
# 8        9          1                 audi 4000      gas      turbo
# 9       10          0       audi 5000s (diesel)      gas      turbo
# 10      11          2                  bmw 320i      gas        std
# 11      12          0                  bmw 320i      gas        std
# 12      13          0                    bmw x1      gas        std
# ...

# %%
car_df.shape
# Out:
# (205, 26)

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# car_ID              205 non-null int64
# symboling           205 non-null int64
# CarName             205 non-null object
# fueltype            205 non-null object
# aspiration          205 non-null object
# doornumber          205 non-null object
# carbody             205 non-null object
# drivewheel          205 non-null object
# enginelocation      205 non-null object
# wheelbase           205 non-null float64
# carlength           205 non-null float64
# carwidth            205 non-null float64
# carheight           205 non-null float64
# curbweight          205 non-null int64
# enginetype          205 non-null object
# cylindernumber      205 non-null object
# enginesize          205 non-null int64
# fuelsystem          205 non-null object
# boreratio           205 non-null float64
# stroke              205 non-null float64
# compressionratio    205 non-null float64
# ...

# %%
car_df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# ## Data Cleaning and Preparation

# %%
round(car_df.isnull().sum()/len(car_df.index), 2)*100
# Out:
# car_ID              0.0
# symboling           0.0
# CarName             0.0
# fueltype            0.0
# aspiration          0.0
# doornumber          0.0
# carbody             0.0
# drivewheel          0.0
# enginelocation      0.0
# wheelbase           0.0
# carlength           0.0
# carwidth            0.0
# carheight           0.0
# curbweight          0.0
# enginetype          0.0
# cylindernumber      0.0
# enginesize          0.0
# fuelsystem          0.0
# boreratio           0.0
# stroke              0.0
# compressionratio    0.0
# horsepower          0.0
# peakrpm             0.0
# citympg             0.0
# highwaympg          0.0
# price               0.0
# dtype: float64

# %%
car_df=car_df.drop_duplicates()

# %%
car_df.drop('car_ID',axis=1,inplace=True)

# %%
CompanyName = car_df['CarName'].apply(lambda x : x.split(' ')[0])
car_df.insert(3,"CompanyName",CompanyName)
car_df.drop(['CarName'],axis=1,inplace=True)
car_df.head()
# Out:
#    symboling fueltype  CompanyName aspiration doornumber      carbody  \
# 0          3      gas  alfa-romero        std        two  convertible
# 1          3      gas  alfa-romero        std        two  convertible
# 2          1      gas  alfa-romero        std        two    hatchback
# 3          2      gas         audi        std       four        sedan
# 4          2      gas         audi        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 0        rwd          front       88.6      168.8  ...         130
# 1        rwd          front       88.6      168.8  ...         130
# 2        rwd          front       94.5      171.2  ...         152
# 3        fwd          front       99.8      176.6  ...         109
# 4        4wd          front       99.4      176.6  ...         136
#
#    fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# ...

# %%
car_df.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
car_df.CompanyName = car_df.CompanyName.str.lower()

def replace_name(a,b):
    car_df.CompanyName.replace(a,b,inplace=True)

replace_name('maxda','mazda')
replace_name('porcshce','porsche')
replace_name('toyouta','toyota')
replace_name('vokswagen','volkswagen')
replace_name('vw','volkswagen')

car_df.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
car_df.columns
# Out:
# Index(['symboling', 'fueltype', 'CompanyName', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %% [markdown]
# ## Data Visualization

# %%
sns.pairplot(car_df)
plt.show()

# %%
plt.figure(figsize = (20, 15))
cor=car_df.corr()
ax = sns.heatmap(cor, annot = True, cmap="YlGnBu")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %% [markdown]
# From this, we can have a general sense of which features are related to price. We can spot some features which has some kind of positive relationships going on with the dependent price variable like,
#
# 1. wheelbase,
# 2. carlength,
# 3. carwidth,
# 4. curbweight,
# 5. enginesize,
# 6. boreratio,
# 7. horsepower.
# However, there are also a few variables showing a negative relationship with price variable like,
# 8. citympg,
# 9. highwaympg.

# %%
plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
plt.title('Car Price Distribution Plot')
sns.distplot(car_df.price)

plt.subplot(1,2,2)
plt.title('Car Price Spread')
sns.boxplot(y=car_df.price)

plt.show()

# %%
car_df.price.describe(percentiles = [0.25,0.50,0.75,0.85,0.90,1])
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# 85%      18500.000000
# 90%      22563.000000
# 100%     45400.000000
# max      45400.000000
# Name: price, dtype: float64

# %% [markdown]
# #### Inference :
# 1. The plot shows that most prices in the dataset are low.
# 2. There is a difference between the mean and the median of the price distribution.
# 3. The data points indicates a high variance in the car prices.

# %%
plt.figure(figsize=(20, 6))

plt.subplot(1,3,1)
plt1 = car_df.CompanyName.value_counts().plot('bar')
plt.title('Companies Histogram')
plt1.set(xlabel = 'Car company', ylabel='Frequency of company')

plt.subplot(1,3,2)
plt1 = car_df.fueltype.value_counts().plot('bar')
plt.title('Fuel Type Histogram')
plt1.set(xlabel = 'Fuel Type', ylabel='Frequency of fuel type')

plt.subplot(1,3,3)
plt1 = car_df.carbody.value_counts().plot('bar')
plt.title('Car Type Histogram')
plt1.set(xlabel = 'Car Type', ylabel='Frequency of Car type')

plt.show()

# %% [markdown]
# #### Inference:
# 1. Toyota seemed to be the most popular company.
# 2. No. of gas fueled cars > No. of diesel cars
# 3. Top preference in car type : Sedan

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Symboling Histogram')
sns.countplot(car_df.symboling, palette=("cubehelix"))

plt.subplot(1,2,2)
plt.title('Symboling vs Price')
sns.boxplot(x=car_df.symboling, y=car_df.price, palette=("cubehelix"))

plt.show()

# %% [markdown]
# Inference :
# 1. It seems that cars the symboling with 0 and 1 values are sold the most
# 2. The cars with -1 symboling seems to be high priced.
# 3. It is seen symboling with 3 value has the price range similar to -2 value. There is a dip in price at symboling 1.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Engine Type Histogram')
sns.countplot(car_df.enginetype, palette=("cubehelix"))

plt.subplot(1,2,2)
plt.title('Engine Type vs Price')
sns.boxplot(x=car_df.enginetype, y=car_df.price, palette=("cubehelix"))

plt.show()

df = pd.DataFrame(car_df.groupby(['enginetype'])['price'].mean().sort_values(ascending = False))
df.plot.bar(figsize=(8,6))
plt.title('Engine Type vs Average Price')
plt.show()

# %% [markdown]
# #### Inference :
# 1. Most favoured engine type: ohc.
# 2. ohcv has the highest price range, ohc and ohcf have the low price range.

# %%
plt.figure(figsize=(25, 6))

df = pd.DataFrame(car_df.groupby(['CompanyName'])['price'].mean().sort_values(ascending = False))
df.plot.bar()
plt.title('Company Name vs Average Price')
plt.show()

df = pd.DataFrame(car_df.groupby(['fueltype'])['price'].mean().sort_values(ascending = False))
df.plot.bar()
plt.title('Fuel Type vs Average Price')
plt.show()

df = pd.DataFrame(car_df.groupby(['carbody'])['price'].mean().sort_values(ascending = False))
df.plot.bar()
plt.title('Car Type vs Average Price')
plt.show()

# %% [markdown]
# #### Inference :
#
# 1. `Jaguar` and `Buick` have highest average price.
# 2. `diesel` has higher average price than  gas.
# 3. `hardtop` and `convertible` have higher average price

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.title('Door Number Histogram')
sns.countplot(car_df.doornumber, palette=("cubehelix"))

plt.subplot(1,2,2)
plt.title('Door Number vs Price')
sns.boxplot(x=car_df.doornumber, y=car_df.price, palette=("cubehelix"))

plt.show()

plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.title('Aspiration Histogram')
sns.countplot(car_df.aspiration, palette=("cubehelix"))

plt.subplot(1,2,2)
plt.title('Aspiration vs Price')
sns.boxplot(x=car_df.aspiration, y=car_df.price, palette=("cubehelix"))

plt.show()

# %% [markdown]
# #### Inference :
#
# 1. doornumber variable is not affecting the price much.
# 2. It is seen that aspiration with turbo have higher price range than the std

# %%
def countplt(x,fig):
    plt.subplot(4,2,fig)
    plt.title(x+ ' histogram')
    sns.countplot(car_df[x],palette=("plasma"))
    plt.subplot(4,2,(fig+1))
    plt.title(x+' vs Price')
    sns.boxplot(x=car_df[x], y=car_df.price, palette=("plasma"))
    
plt.figure(figsize=(15,20))

countplt('enginelocation', 1)
countplt('cylindernumber', 3)
countplt('fuelsystem', 5)
countplt('drivewheel', 7)

plt.tight_layout()

# %% [markdown]
# #### Inference :
#
# 1. Very few datapoints for enginelocation categories to make an inference.
# 2. Most common number of cylinders are four, six and five. Though eight cylinders have the highest price range.
# 3. mpfi and 2bbl are most common type of fuel systems. mpfi and idi having the highest price range.
# 4. Most prefered: rwd drivewheel. rwd have the highest price range

# %%
def plotnum(x,fig):
    plt.subplot(5,2,fig)
    plt.scatter(car_df[x],car_df['price'])
    plt.title(x+' vs Price')
    plt.ylabel('Price')
    plt.xlabel(x)

plt.figure(figsize=(10,20))

plotnum('carlength', 1)
plotnum('carwidth', 2)
plotnum('carheight', 3)
plotnum('curbweight', 4)

plt.tight_layout()

# %% [markdown]
# #### Inference :
# 1. carwidth, carlength and curbweight have a poitive correlation with price.
# 2. carheight doesn't show any significant correlation with price.

# %%
def car_scatter(x,y,z):
    sns.pairplot(car_df, x_vars=[x,y,z], y_vars='price',height=4, aspect=1, kind='scatter')
    plt.show()

car_scatter('enginesize', 'boreratio', 'stroke')
car_scatter('compressionratio', 'horsepower', 'peakrpm')
car_scatter('wheelbase', 'citympg', 'highwaympg')

# %% [markdown]
# #### Inference :
#
# 1. `enginesize`, `boreratio`, `horsepower`, `wheelbase` - have a positive correlation with price.
# 2. `citympg`, `highwaympg` - have a negative correlation with price.

# %%
np.corrcoef(car_df['carlength'], car_df['carwidth'])[0, 1]
# Out:
# 0.841118268481846

# %%
car_df['fueleconomy'] = (0.55 * car_df['citympg']) + (0.45 * car_df['highwaympg'])
car_df['price'] = car_df['price'].astype('int')
temp = car_df.copy()
table = temp.groupby(['CompanyName'])['price'].mean()
temp = temp.merge(table.reset_index(), how='left',on='CompanyName')
bins = [0,10000,20000,40000]
car_df_bin=['Budget','Medium','Highend']
car_df['carsrange'] = pd.cut(temp['price_y'],bins,right=False,labels=car_df_bin)
car_df.head(15)
# Out:
#     symboling fueltype  CompanyName aspiration doornumber      carbody  \
# 0           3      gas  alfa-romero        std        two  convertible
# 1           3      gas  alfa-romero        std        two  convertible
# 2           1      gas  alfa-romero        std        two    hatchback
# 3           2      gas         audi        std       four        sedan
# 4           2      gas         audi        std       four        sedan
# 5           2      gas         audi        std        two        sedan
# 6           1      gas         audi        std       four        sedan
# 7           1      gas         audi        std       four        wagon
# 8           1      gas         audi      turbo       four        sedan
# 9           0      gas         audi      turbo        two    hatchback
# 10          2      gas          bmw        std        two        sedan
# 11          0      gas          bmw        std       four        sedan
# ...

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(8,6))

plt.title('Fuel economy vs Price')
sns.scatterplot(x=car_df['fueleconomy'],y=car_df['price'],hue=car_df['drivewheel'])
plt.xlabel('Fuel Economy')
plt.ylabel('Price')

plt.show()
plt.tight_layout()

# %% [markdown]
# #### Inference :
#
# 1. `fueleconomy` has `negative correlation` with price.

# %%
plt.figure(figsize=(50, 50))

df = pd.DataFrame(car_df.groupby(['fuelsystem','drivewheel','carsrange'])['price'].mean().unstack(fill_value=0))
df.plot.bar()
plt.title('Car Range vs Average Price')
plt.show()

# %% [markdown]
# #### Inference :
#
# 1. High ranged cars prefer `rwd` drivewheel with `idi` or `mpfi` fuelsystem.

# %% [markdown]
# List of significant variables after Visualization and Analysis :
# - Car Range
# - Engine Type
# - Fuel type
# - Car Body
# - Aspiration
# - Cylinder Number
# - Drivewheel
# - Curbweight
# - Car Length
# - Car width
# - Engine Size
# - Boreratio
# - Horse Power
# - Wheel base
# - Fuel Economy

# %%
cars_df2 = car_df[['price', 'fueltype', 'aspiration','carbody', 'drivewheel','wheelbase',
                  'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 
                    'fueleconomy', 'carlength','carwidth', 'carsrange']]
cars_df2.head(15)
# Out:
#     price fueltype aspiration      carbody drivewheel  wheelbase  curbweight  \
# 0   13495      gas        std  convertible        rwd       88.6        2548
# 1   16500      gas        std  convertible        rwd       88.6        2548
# 2   16500      gas        std    hatchback        rwd       94.5        2823
# 3   13950      gas        std        sedan        fwd       99.8        2337
# 4   17450      gas        std        sedan        4wd       99.4        2824
# 5   15250      gas        std        sedan        fwd       99.8        2507
# 6   17710      gas        std        sedan        fwd      105.8        2844
# 7   18920      gas        std        wagon        fwd      105.8        2954
# 8   23875      gas      turbo        sedan        fwd      105.8        3086
# 9   17859      gas      turbo    hatchback        4wd       99.5        3053
# 10  16430      gas        std        sedan        rwd      101.2        2395
# ...

# %%
sns.pairplot(cars_df2)
plt.show()

# %%
def dummyvar(x,df):
    temp = pd.get_dummies(df[x], drop_first = True)
    df = pd.concat([df, temp], axis = 1)
    df.drop([x], axis = 1, inplace = True)
    return df


cars_df2 = dummyvar('fueltype',cars_df2)
cars_df2 = dummyvar('aspiration',cars_df2)
cars_df2 = dummyvar('carbody',cars_df2)
cars_df2 = dummyvar('drivewheel',cars_df2)
cars_df2 = dummyvar('enginetype',cars_df2)
cars_df2 = dummyvar('cylindernumber',cars_df2)
cars_df2 = dummyvar('carsrange',cars_df2)

# %%
cars_df2.head()
# Out:
#    price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 0  13495       88.6        2548         130       3.47         111
# 1  16500       88.6        2548         130       3.47         111
# 2  16500       94.5        2823         152       2.68         154
# 3  13950       99.8        2337         109       3.19         102
# 4  17450       99.4        2824         136       3.19         115
#
#    fueleconomy  carlength  carwidth  gas  ...  ohcv  rotor  five  four  six  \
# 0        23.70      168.8      64.1    1  ...     0      0     0     1    0
# 1        23.70      168.8      64.1    1  ...     0      0     0     1    0
# 2        22.15      171.2      65.5    1  ...     1      0     0     0    1
# 3        26.70      176.6      66.2    1  ...     0      0     0     1    0
# 4        19.80      176.6      66.4    1  ...     0      0     1     0    0
#
#    three  twelve  two  Medium  Highend
# 0      0       0    0       1        0
# ...

# %%
cars_df2.shape
# Out:
# (205, 31)

# %% [markdown]
# # Train-Test Split

# %%
np.random.seed(0)
df_train, df_test = train_test_split(cars_df2, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
scaler = MinMaxScaler()
num_vars = ['wheelbase', 'curbweight', 'enginesize', 'boreratio', 'horsepower','fueleconomy','carlength','carwidth','price']
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#         price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 122  0.068818   0.244828    0.272692    0.139623   0.230159    0.083333
# 125  0.466890   0.272414    0.500388    0.339623   1.000000    0.395833
# 166  0.122110   0.272414    0.314973    0.139623   0.444444    0.266667
# 1    0.314446   0.068966    0.411171    0.260377   0.626984    0.262500
# 199  0.382131   0.610345    0.647401    0.260377   0.746032    0.475000
#
#      fueleconomy  carlength  carwidth  gas  ...  ohcv  rotor  five  four  six  \
# 122     0.530864   0.426016  0.291667    1  ...     0      0     0     1    0
# 125     0.213992   0.452033  0.666667    1  ...     0      0     0     1    0
# 166     0.344307   0.448780  0.308333    1  ...     0      0     0     1    0
# 1       0.244170   0.450407  0.316667    1  ...     0      0     0     1    0
# 199     0.122085   0.775610  0.575000    1  ...     0      0     0     1    0
#
#      three  twelve  two  Medium  Highend
# ...

# %%
df_train.describe()
# Out:
#             price   wheelbase  curbweight  enginesize   boreratio  horsepower  \
# count  143.000000  143.000000  143.000000  143.000000  143.000000  143.000000
# mean     0.219309    0.411141    0.407878    0.241351    0.497946    0.227302
# std      0.215682    0.205581    0.211269    0.154619    0.207140    0.165511
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.067298    0.272414    0.245539    0.135849    0.305556    0.091667
# 50%      0.140343    0.341379    0.355702    0.184906    0.500000    0.191667
# 75%      0.313479    0.503448    0.559542    0.301887    0.682540    0.283333
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        fueleconomy   carlength    carwidth         gas  ...        ohcv  \
# count   143.000000  143.000000  143.000000  143.000000  ...  143.000000
# mean      0.358265    0.525476    0.461655    0.909091  ...    0.062937
# ...

# %%
plt.figure(figsize = (30, 25))
ax=sns.heatmap(df_train.corr(), annot = True, cmap="YlGnBu")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
train_Y = df_train.pop('price')
train_X = df_train

# %% [markdown]
# # Model Building

# %%
lm = LinearRegression()
lm.fit(train_X,train_Y)
rfe = RFE(lm, 10)
rfe = rfe.fit(train_X,train_Y)

# %%
list(zip(train_X.columns,rfe.support_,rfe.ranking_))
# Out:
# [('wheelbase', False, 3),
#  ('curbweight', True, 1),
#  ('enginesize', False, 13),
#  ('boreratio', False, 10),
#  ('horsepower', True, 1),
#  ('fueleconomy', True, 1),
#  ('carlength', False, 11),
#  ('carwidth', True, 1),
#  ('gas', False, 17),
#  ('turbo', False, 18),
#  ('hardtop', False, 2),
#  ('hatchback', True, 1),
#  ('sedan', True, 1),
#  ('wagon', True, 1),
#  ('fwd', False, 16),
#  ('rwd', False, 15),
#  ('dohcv', True, 1),
#  ('l', False, 19),
#  ('ohc', False, 7),
#  ('ohcf', False, 8),
#  ('ohcv', False, 9),
#  ('rotor', False, 21),
#  ('five', False, 6),
#  ('four', False, 4),
#  ('six', False, 5),
#  ('three', False, 14),
#  ('twelve', True, 1),
#  ('two', False, 20),
#  ('Medium', False, 12),
#  ('Highend', True, 1)]

# %%
train_X.columns[rfe.support_]
# Out:
# Index(['curbweight', 'horsepower', 'fueleconomy', 'carwidth', 'hatchback',
#        'sedan', 'wagon', 'dohcv', 'twelve', 'Highend'],
#       dtype='object')

# %%
X_train_rfe = train_X[train_X.columns[rfe.support_]]
X_train_rfe.head()
# Out:
#      curbweight  horsepower  fueleconomy  carwidth  hatchback  sedan  wagon  \
# 122    0.272692    0.083333     0.530864  0.291667          0      1      0
# 125    0.500388    0.395833     0.213992  0.666667          1      0      0
# 166    0.314973    0.266667     0.344307  0.308333          1      0      0
# 1      0.411171    0.262500     0.244170  0.316667          0      0      0
# 199    0.647401    0.475000     0.122085  0.575000          0      0      1
#
#      dohcv  twelve  Highend
# 122      0       0        0
# 125      0       0        1
# 166      0       0        0
# 1        0       0        0
# 199      0       0        0

# %%
def build_model(X,y):
    X = sm.add_constant(X) 
    lm = sm.OLS(y,X).fit() 
    print(lm.summary()) 
    return X
    
def checkVIF(X):
    vif = pd.DataFrame()
    vif['Features'] = X.columns
    vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    return(vif)

# %% [markdown]
# ## Model 1

# %%
X_train_new = build_model(X_train_rfe,train_Y)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     172.1
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):           1.29e-70
# Time:                        19:09:15   Log-Likelihood:                 205.85
# No. Observations:                 143   AIC:                            -389.7
# Df Residuals:                     132   BIC:                            -357.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0947      0.042     -2.243      0.027      -0.178      -0.011
# ...

# %% [markdown]
# p-value of twelve is higher than the significance value of 0.05, so it will be dropped.

# %%
X_train_new = X_train_rfe.drop(["twelve"], axis = 1)

# %% [markdown]
# ## Model 2

# %%
X_train_new = build_model(X_train_new,train_Y)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.927
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     187.9
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):           4.25e-71
# Time:                        19:09:15   Log-Likelihood:                 204.17
# No. Observations:                 143   AIC:                            -388.3
# Df Residuals:                     133   BIC:                            -358.7
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0764      0.041     -1.851      0.066      -0.158       0.005
# ...

# %%
X_train_new = X_train_new.drop(["fueleconomy"], axis = 1)

# %% [markdown]
# ## Model 3

# %%
X_train_new = build_model(X_train_new,train_Y)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     209.5
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):           7.85e-72
# Time:                        19:09:15   Log-Likelihood:                 203.07
# No. Observations:                 143   AIC:                            -388.1
# Df Residuals:                     134   BIC:                            -361.5
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0305      0.026     -1.165      0.246      -0.082       0.021
# ...

# %%
checkVIF(X_train_new)
# Out:
#      Features    VIF
# 0       const  26.90
# 1  curbweight   8.10
# 5       sedan   6.07
# 4   hatchback   5.63
# 3    carwidth   5.14
# 2  horsepower   3.61
# 6       wagon   3.58
# 8     Highend   1.63
# 7       dohcv   1.46

# %% [markdown]
# Dropping curbweight because of high VIF value.

# %%
X_train_new = X_train_new.drop(["curbweight"], axis = 1)

# %% [markdown]
# ## Model 4

# %%
X_train_new = build_model(X_train_new,train_Y)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                     215.9
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):           4.70e-70
# Time:                        19:09:16   Log-Likelihood:                 195.77
# No. Observations:                 143   AIC:                            -375.5
# Df Residuals:                     135   BIC:                            -351.8
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0319      0.027     -1.161      0.248      -0.086       0.022
# ...

# %%
checkVIF(X_train_new)
# Out:
#      Features    VIF
# 0       const  26.89
# 4       sedan   6.06
# 3   hatchback   5.54
# 5       wagon   3.47
# 1  horsepower   2.50
# 2    carwidth   2.22
# 7     Highend   1.56
# 6       dohcv   1.21

# %% [markdown]
# Dropping sedan because of high VIF value.

# %%
X_train_new = X_train_new.drop(["sedan"], axis = 1)

# %% [markdown]
# ## Model 5

# %%
X_train_new = build_model(X_train_new,train_Y)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     237.6
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):           1.68e-69
# Time:                        19:09:17   Log-Likelihood:                 191.46
# No. Observations:                 143   AIC:                            -368.9
# Df Residuals:                     136   BIC:                            -348.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0934      0.018     -5.219      0.000      -0.129      -0.058
# ...

# %% [markdown]
# Dropping wagon because of high p-value.

# %%
X_train_new = X_train_new.drop(["wagon"], axis = 1)

# %% [markdown]
# ## Model 6

# %%
X_train_new = build_model(X_train_new,train_Y)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     284.8
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):           1.57e-70
# Time:                        19:09:17   Log-Likelihood:                 190.93
# No. Observations:                 143   AIC:                            -369.9
# Df Residuals:                     137   BIC:                            -352.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0970      0.018     -5.530      0.000      -0.132      -0.062
# ...

# %% [markdown]
# ## Model 7

# %% [markdown]
# **Dropping dohcv**

# %%
X_train_new = X_train_new.drop(["dohcv"], axis = 1)
X_train_new = build_model(X_train_new,train_Y)
checkVIF(X_train_new)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     308.0
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):           1.04e-67
# Time:                        19:09:17   Log-Likelihood:                 181.06
# No. Observations:                 143   AIC:                            -352.1
# Df Residuals:                     138   BIC:                            -337.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0824      0.018     -4.480      0.000      -0.119      -0.046
# ...

# %% [markdown]
# # Residual Analysis

# %%
lm = sm.OLS(train_Y,X_train_new).fit()
y_train_price = lm.predict(X_train_new)

# %%
fig = plt.figure()
sns.distplot((train_Y - y_train_price), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                 
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# # Prediction and Evaluation

# %%
num_vars = ['wheelbase', 'curbweight', 'enginesize', 'boreratio', 'horsepower','fueleconomy','carlength','carwidth','price']
df_test[num_vars] = scaler.fit_transform(df_test[num_vars])

# %%
y_test = df_test.pop('price')
X_test = df_test

# %%
X_train_new = X_train_new.drop('const',axis=1)

X_test_new = X_test[X_train_new.columns]
X_test_new = sm.add_constant(X_test_new)

# %%
y_pred = lm.predict(X_test_new)

# %%
from sklearn.metrics import r2_score 
r2_score(y_test, y_pred)
# Out:
# 0.8614595209022033

# %%
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              
plt.xlabel('y_test', fontsize=18)                          
plt.ylabel('y_pred', fontsize=16)
# Out:
# Text(0, 0.5, 'y_pred')

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     308.0
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):           1.04e-67
# Time:                        19:14:47   Log-Likelihood:                 181.06
# No. Observations:                 143   AIC:                            -352.1
# Df Residuals:                     138   BIC:                            -337.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0824      0.018     -4.480      0.000      -0.119      -0.046
# ...

# %% [markdown]
# #### Inference :
#
# 1. R-sqaured and Adjusted R-squared (extent of fit) : 0.899 and 0.896 (90% variance explained).
# 2. F-stats and Prob(F-stats) (overall model fit) : 308.0 and 1.04e-67(approx. 0.0) (Model fit is significant and explained 90% variance).
# 3. p-values - p-values for all the coefficients are less than the significance level of 0.05.(all the predictors are statistically significant).

# %% [markdown]
# Suggestions:
# The chinese company Geely Automotives can use the following points for a profitble car design.
#
# - Average US car price: 13000 USD(approx).
# - symboling: moderate (0,1)
# - Carbody: Sedan
# - fueltype: gas
# - aspiration: standard
# - doornumbers: four
# - drivewheel: forward
# - engine location: front
# - engine type: ohc
# - cylinderNumber: four
# - fuelSystem: mpfi
